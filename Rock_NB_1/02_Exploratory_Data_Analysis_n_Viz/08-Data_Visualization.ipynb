# %% [markdown]
# # With Matplotlib

# %% [markdown]
# 1. Library for publication-quality plots
# 2. Highly configurable
# 3. Provides an alternative matlab-like interface

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Let's start by a simple plot :  no big deal

# %%
#with two list of numbers 
a = [1,10,20,5.5,12]
b =[3,2,4,8,9]

# %%
plt.plot(a,b)

# %%
import numpy as np

# %%
x = np.linspace(0 , 2*np.pi,30)
y = np.sin(x)

# %%
plt.plot(x,y)

# %% [markdown]
# ## Several plots in the same figure

# %%
#Another plot may be added to it
x = np.linspace(0 , 2*np.pi,30)
y = np.sin(x)
z = np.cos(x)
plt.plot(x,y)
plt.plot(x,z)

# %% [markdown]
# ### Subplots

# %% [markdown]
# ### More specificity and colors to the same plot

# %%
years = [1950, 1960, 1970, 1980, 1990, 2000, 2010]
gdp = [300.2, 543.3, 1075.9, 2862.5, 5979.6, 10289.7, 14958.3]

plt.plot(years , gdp, color = 'g' , marker = 'o' , linestyle='--')
plt.text(1950 , 300.2, 'First')
plt.text(1990 , 5979.6, 'Fifth')
# Out:
# Text(1990, 5979.6, 'Fifth')

# %%
plt.plot(years , gdp, 'cH')

# %%
import pandas as pd

# %%
df = pd.read_csv('data/gapminder.tsv', sep = '\t')

# %%
df.head()
# Out:
#    country continent  year  lifeExp       pop    gdpPercap
# 0  Algeria    Africa  1952   43.077   9279525  2449.008185
# 1  Algeria    Africa  1957   45.685  10270856  3013.976023
# 2  Algeria    Africa  1962   48.303  11000948  2550.816880
# 3  Algeria    Africa  1967   51.407  12760499  3246.991771
# 4  Algeria    Africa  1972   54.518  14760787  4182.663766

# %%
#df.groupby(['year','continent','country'])['lifeExp','gdpPercap'].mean().reset_index()
df1 = df[(df['continent']=='Africa') & (df['country']=='Cameroon')] 
#Could someone tell me what I did wrong (redundant) here?

# %%
df1.head()
# Out:
#       country continent  year  lifeExp      pop    gdpPercap
# 204  Cameroon    Africa  1952   38.523  5009067  1172.667655
# 205  Cameroon    Africa  1957   40.428  5359923  1313.048099
# 206  Cameroon    Africa  1962   42.643  5793633  1399.607441
# 207  Cameroon    Africa  1967   44.799  6335506  1508.453148
# 208  Cameroon    Africa  1972   47.049  7021028  1684.146528

# %%
df1[df1['year']>1995]
# Out:
#       country continent  year  lifeExp       pop    gdpPercap
# 213  Cameroon    Africa  1997   52.199  14195809  1694.337469
# 214  Cameroon    Africa  2002   49.856  15929988  1934.011449
# 215  Cameroon    Africa  2007   50.430  17696293  2042.095240

# %%
plt.plot(df1['year'], df1["lifeExp"])
plt.xlabel('years')
plt.ylabel('Life Expectancy')
plt.legend(loc = 'best')
#some features migt be added like title , labels (x,y) , legend

# %% [markdown]
# Let's add another plot on the same figure

# %%
plt.plot(df1['year'], df1["lifeExp"])
plt.plot(df1['year'], df1["gdpPercap"])
plt.xlabel('years')
plt.ylabel('Life Expectancy')
plt.legend(loc = 'best')
#some features migt be added like title , labels (x,y) , legend

# %%
plt.figure(figsize=(8,3), dpi=400)
plt.subplot(1,3,1)
plt.plot(df1['year'], df1["lifeExp"], 'c-')
plt.xlabel('years')
plt.ylabel('Life Expectancy')
plt.legend(loc = 'best')
plt.subplot(1,3,3)
plt.plot(df1['year'], df1["gdpPercap"] , 'g-')
plt.text(1997 , 1694.337469, 'bad')
plt.xlabel('years')
plt.ylabel('Life Expectancy')
plt.legend(loc = 'best')

# %% [markdown]
# ## Other ways of representing data are available in Python

# %% [markdown]
# ### Histograms

# %%
plt.figure(figsize=(8,4), dpi=100)
plt.bar(np.arange(len(df1['lifeExp'])), df1['lifeExp'])
plt.xticks(np.arange(len(df1['lifeExp'])),list(df1['year']))
# Out:
# ([<matplotlib.axis.XTick at 0x7f21d0c40518>,
# ...
#  <a list of 12 Text xticklabel objects>)

# %%
list(df1['year'])
# Out:
# [1952, 1957, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002, 2007]

# %%
labels = ['Nokia','Samsung','Apple','Lumia']
values = [10,30,45,15]
colors = ['yellow','green','red','blue']
explode = [0,0,0,0] #emphasize on specific part of the pie
plt.title('A Pie Chart')
plt.pie(values,labels=labels,colors=colors,explode=explode,
shadow=True,autopct='%1.1f%%',startangle=180)  #autopct to specify the percentage needed
plt.axis('equal')
plt.show()

# %%
df2=df.groupby(['year','continent'])['lifeExp'].mean()
df21=pd.DataFrame(df2).reset_index()
df21.head()
# Out:
#    year continent    lifeExp
# 0  1952    Africa  39.135500
# 1  1952  Americas  53.279840
# 2  1952      Asia  46.861688
# 3  1952    Europe  64.725000
# 4  1952   Oceania  69.255000

# %%
np.zeros(5)
# Out:
# array([0., 0., 0., 0., 0.])

# %%
labels = df21[df21['year']==1952]['continent']
values= df21[df21['year']==1952]['lifeExp']
colors = ['b','g', 'r', 'c', 'm']
explode = np.zeros(len(df21[df21['year']==1952]))
plt.title('Life Expectancy in 1952')
plt.pie(values,labels=labels,colors=colors,explode=explode,
shadow=False,autopct='%1.2f%%',startangle=180)  #autopct to specify the percentage needed
plt.axis('equal')
plt.show()

# %%
labels = df21[df21['year']==1952]['continent']
values= df21[df21['year']==1952]['lifeExp']
colors = ['b','g', 'r', 'c', 'm']
#explode = np.zeros(len(df21[df21['year']==1952]))
explode = [0.5,0,0,0,0]
plt.title('Life Expectancy in 1952')
plt.pie(values,labels=labels,colors=colors,explode=explode,
shadow=False,autopct='%1.1f%%',startangle=180)  #autopct to specify the percentage needed
plt.axis('equal')
plt.show()

# %% [markdown]
# Other plots exist in 3D as well

# %%
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

# %%
def f(x):
    return x +5

# %%
interact(f, x= (-5 , 10 , 1));

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def sincos( a , b):
    x = np.linspace(-2*np.pi , 2*np.pi,100)
    plt.plot (x , a*np.sin(x + b ) , label =  "$a \sin(x) +b$")
    plt.plot (x , a*np.cos(x) , 'ro--' , label =  "$a \cos(x)$")
    plt.xlabel("$x$" , size = 20)
    plt.ylabel("$\sin(x)  , \cos(x)$" , size = 20)
    plt.legend()
    plt.xlim( -2*np.pi  , 2*np.pi)
    plt.ylim( -2 , 2)

# %%
sincos( 1 , 3)

# %%
widgets.interact(sincos , a = (-5 , 5 , 0.1)  , b= (-5 , 5 , 0.1) )
